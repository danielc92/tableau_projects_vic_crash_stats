# %% [markdown]
# ## Import Modules/

# %%
import pandas
import requests

# %% [markdown]
# ## Import Data

# %%
data = pandas.read_excel("/users/danielcorcoran/desktop/mobile_speed_camera_data/Mobile Camera Locations August 2018(1).xlsx")

# %%
data.head(3)
# Out:
#   MOBILE SAFETY CAMERA LOCATION DESCRIPTION REPORT   Unnamed: 1   Unnamed: 2  \
# 0                                         LOCATION       SUBURB  Reason Code
# 1                                        Agar Road  CORONET BAY           BC
# 2                                 Aitken Boulevard  CRAIGIEBURN          ABC
#
#    Unnamed: 3
# 0  Audit Date
# 1    Jul-2018
# 2    Dec-2017

# %% [markdown]
# ## Manipulate Data

# %%
headers = data.loc[0].tolist()
headers
# Out:
# ['LOCATION', 'SUBURB', 'Reason Code', 'Audit Date']

# %%
data.columns = headers

# %%
data.head()
# Out:
#            LOCATION         SUBURB  Reason Code  Audit Date
# 0          LOCATION         SUBURB  Reason Code  Audit Date
# 1         Agar Road    CORONET BAY           BC    Jul-2018
# 2  Aitken Boulevard    CRAIGIEBURN          ABC    Dec-2017
# 3  Aitken Boulevard  ROXBURGH PARK          ABC    Dec-2017
# 4     Aitken Street      ALEXANDRA            C    Apr-2018

# %%
data.drop(0, axis = 0, inplace = True)

# %%
data.head()
# Out:
#            LOCATION         SUBURB Reason Code Audit Date
# 1         Agar Road    CORONET BAY          BC   Jul-2018
# 2  Aitken Boulevard    CRAIGIEBURN         ABC   Dec-2017
# 3  Aitken Boulevard  ROXBURGH PARK         ABC   Dec-2017
# 4     Aitken Street      ALEXANDRA           C   Apr-2018
# 5     Albert Avenue        BORONIA           C   Jan-2018

# %%
data.reset_index(drop = True, inplace = True)

# %%
data.shape
# Out:
# (1677, 5)

# %%
data["full_location"] = data["LOCATION"] +  ", " + data["SUBURB"] + ", VICTORIA, AUSTRALIA"

# %%
data.head()
# Out:
#            LOCATION         SUBURB Reason Code Audit Date  \
# 0         Agar Road    CORONET BAY          BC   Jul-2018
# 1  Aitken Boulevard    CRAIGIEBURN         ABC   Dec-2017
# 2  Aitken Boulevard  ROXBURGH PARK         ABC   Dec-2017
# 3     Aitken Street      ALEXANDRA           C   Apr-2018
# 4     Albert Avenue        BORONIA           C   Jan-2018
#
#                                        full_location
# 0        Agar Road, CORONET BAY, VICTORIA, AUSTRALIA
# 1  Aitken Boulevard, CRAIGIEBURN, VICTORIA, AUSTR...
# 2  Aitken Boulevard, ROXBURGH PARK, VICTORIA, AUS...
# 3      Aitken Street, ALEXANDRA, VICTORIA, AUSTRALIA
# 4        Albert Avenue, BORONIA, VICTORIA, AUSTRALIA

# %%
data.to_csv("aug_mobile_cameras.csv", index_label="ROW_INDEX")

# %% [markdown]
# ## Geocoding Function

# %%
def return_address_dictionary(address):
    base_url = "https://maps.googleapis.com/maps/api/geocode/json?address="
    full_url = base_url + address
    request = requests.get(full_url)
    result = request.json()
    
    longitude = result["results"][0]["geometry"]["location"]["lng"]
    latitude = result["results"][0]["geometry"]["location"]["lat"]
    formatted_address = result["results"][0]["formatted_address"]

    return longitude, latitude, formatted_address

# %%
for index in range(data.shape[0]): #Adjust index ranges upon failures
    
    address = data.loc[index, "full_location"]
    long, lat, address = return_address_dictionary(address)
    
    print(index, long, lat, address, sep = "|")
# Out:
# -------------------------------------------------------------------
# SSLEOFError                       Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     813                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 814                     self.do_handshake()
#     815
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self, block)
#    1067                 self.settimeout(None)
# -> 1068             self._sslobj.do_handshake()
#    1069         finally:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in do_handshake(self)
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#
# SSLEOFError: EOF occurred in violation of protocol (_ssl.c:833)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                     Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Agar%20Road,%20CORONET%20BAY,%20VICTORIA,%20AUSTRALIA (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:833)'),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                          Traceback (most recent call last)
# <ipython-input-22-b86adafcd8ed> in <module>()
#       2
#       3     address = data.loc[index, "full_location"]
# ----> 4     long, lat, address = return_address_dictionary(address)
#       5     print(index, long, lat, address, sep = "|")
#
# <ipython-input-21-50643f333609> in return_address_dictionary(address)
#       2     base_url = "https://maps.googleapis.com/maps/api/geocode/json?address="
#       3     full_url = base_url + address
# ----> 4     request = requests.get(full_url)
#       5     result = request.json()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Agar%20Road,%20CORONET%20BAY,%20VICTORIA,%20AUSTRALIA (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:833)'),))

# %%
data.head()
# Out:
#            LOCATION         SUBURB Reason Code Audit Date  \
# 0         Agar Road    CORONET BAY          BC   Jul-2018
# 1  Aitken Boulevard    CRAIGIEBURN         ABC   Dec-2017
# 2  Aitken Boulevard  ROXBURGH PARK         ABC   Dec-2017
# 3     Aitken Street      ALEXANDRA           C   Apr-2018
# 4     Albert Avenue        BORONIA           C   Jan-2018
#
#                      full_location
# 0           Agar Road, CORONET BAY
# 1    Aitken Boulevard, CRAIGIEBURN
# 2  Aitken Boulevard, ROXBURGH PARK
# 3         Aitken Street, ALEXANDRA
# 4           Albert Avenue, BORONIA

# %%
data["row_index"] = data.index

# %%
data.head()
# Out:
#            LOCATION         SUBURB Reason Code Audit Date  \
# 0         Agar Road    CORONET BAY          BC   Jul-2018
# 1  Aitken Boulevard    CRAIGIEBURN         ABC   Dec-2017
# 2  Aitken Boulevard  ROXBURGH PARK         ABC   Dec-2017
# 3     Aitken Street      ALEXANDRA           C   Apr-2018
# 4     Albert Avenue        BORONIA           C   Jan-2018
#
#                      full_location  row_index
# 0           Agar Road, CORONET BAY          0
# 1    Aitken Boulevard, CRAIGIEBURN          1
# 2  Aitken Boulevard, ROXBURGH PARK          2
# 3         Aitken Street, ALEXANDRA          3
# 4           Albert Avenue, BORONIA          4

# %% [markdown]
# ## Bring in results data (excel sheet created from geocoding results)

# %%
results_data = pandas.read_excel("/users/danielcorcoran/desktop/geocode_results.xlsx")

# %%
results_data.head()
# Out:
#    index   longitude   latitude  \
# 0    0.0  145.446520 -38.435757
# 1    1.0  144.909917 -37.594783
# 2    2.0  144.914952 -37.624340
# 3    3.0  145.703606 -37.187826
# 4    4.0  145.297632 -37.854281
#
#                                 corrected address
# 0        Agar Rd, Coronet Bay VIC 3984, Australia
# 1    Aitken Blvd, Craigieburn VIC 3064, Australia
# 2  Aitken Blvd, Roxburgh Park VIC 3064, Australia
# 3        Aitken St, Alexandra VIC 3714, Australia
# 4         Albert Ave, Boronia VIC 3155, Australia

# %% [markdown]
# ## Merge to original

# %%
merged_data = pandas.merge(left = data,
                          right = results_data,
                          how = "left",
                          left_on = "row_index",
                          right_on = "index")

# %%
merged_data["extracted_on"] = "2018-August-06"

# %%
merged_data.to_csv("geocoded_mobile_speed_cameras_august_6_2018.csv", sep = ",", index = False)

# %% [markdown]
# ## Bring merged data back in

# %%
merged_data = pandas.read_csv("/users/danielcorcoran/desktop/mobile_speed_camera_data/geocoded_mobile_speed_cameras_august_6_2018.csv")

# %%
merged_data.loc[0,"longitude"]
# Out:
# 145.4465196

# %%
merged_data
# Out:
#                         LOCATION              SUBURB Reason Code Audit Date  \
# 0                      Agar Road         CORONET BAY          BC   Jul-2018
# 1               Aitken Boulevard         CRAIGIEBURN         ABC   Dec-2017
# 2               Aitken Boulevard       ROXBURGH PARK         ABC   Dec-2017
# 3                  Aitken Street           ALEXANDRA           C   Apr-2018
# 4                  Albert Avenue             BORONIA           C   Jan-2018
# 5                    Albert Road            WARRAGUL         ABC   Apr-2018
# 6                Alexanders Road             MORWELL         ABC   Apr-2018
# 7                   Allan Street             KYABRAM           C   Apr-2018
# 8                 Allenby Avenue           RESERVOIR           C   Apr-2018
# 9                    Allies Road          MYERS FLAT          AC   Jul-2018
# 10                   Alma Street          TOOTGAROOK          BC   May-2018
# 11          Ambrose Treacy Drive            BUNDOORA          BC   Apr-2018
# 12                   Anakie Road           BELL PARK          BC   Apr-2018
# 13                 Anderson Road             FAWKNER           C   Dec-2017
# 14                 Anderson Road            SUNSHINE         ABC   Jul-2018
# 15                 Anglesea Road    FRESHWATER CREEK          BC   Apr-2018
# 16                  Anzac Parade            BANDIANA           C   Apr-2018
# 17                    Anzac Road           TRAFALGAR           B   Apr-2018
# 18                   Apollo Road       TAYLORS LAKES          BC   Jul-2018
# 19                   Ararat Road             STAWELL           B   Jul-2018
# 20         Ararat-Halls Gap Road            JALLUKAR          AC   Jul-2018
# 21         Ararat-Halls Gap Road             MOYSTON          AC   Jul-2018
# 22         Ararat-Halls Gap Road             POMONAL         ABC   Jul-2018
# 23          Ararat-Mortlake Road              ARARAT           B   Jul-2018
# 24                Armstrong Road  WYNDHAM VALE (NWB)         ABC   Jun-2018
# 25              Armstrong Street           ELLIMINYT         ABC   Apr-2018
# 26                     Army Road            PAKENHAM           B   Jul-2018
# 27                     Army Road      PAKENHAM UPPER          BC   May-2018
# 28                 Arthur Street           ST ALBANS           C   Jul-2018
# 29            Arthurs Creek Road       ARTHURS CREEK         ABC   Jul-2018
# ...                          ...                 ...         ...        ...
# 1647   Wodonga-Yackandandah Road       STAGHORN FLAT           C   Apr-2018
# 1648              Wollaston Road         WARRNAMBOOL           C   Apr-2018
# 1649                  Wonga Road            RINGWOOD          AC   Feb-2018
# 1650                 Wood Street            FLINDERS          BC   May-2018
# 1651                 Wood Street             PRESTON           C   Apr-2018
# 1652             Woodland Street          STRATHMORE           C   Dec-2017
# 1653              Woodmason Road             BORONIA          BC   Jan-2018
# 1654            Woods Point Road      EAST WARBURTON         ABC   Mar-2018
# 1655            Woods Point Road      MCMAHONS CREEK         ABC   Mar-2018
# 1656          Woori Yallock Road            COCKATOO         ABC   Jul-2018
# 1657          Woori Yallock Road             NANGANA         ABC   May-2018
# 1658               Woorinen Road           SWAN HILL           C   Apr-2018
# 1659      Woorinen-Vinifera Road      WOORINEN NORTH          BC   Apr-2018
# 1660      Woorinen-Vinifera Road      WOORINEN SOUTH          BC   Apr-2018
# 1661                Worsley Road           BANGHOLME          BC   Apr-2018
# 1662               Wright Street            SUNSHINE         ABC   Jul-2018
# 1663                 Wyandra Way            ROWVILLE          BC   Mar-2018
# 1664              Yallambie Road           YALLAMBIE          AC   Jul-2018
# 1665               Yan Yean Road              DOREEN         ABC   Apr-2018
# 1666               Yan Yean Road              PLENTY          BC   Jul-2018
# 1667               Yan Yean Road           YARRAMBAT          BC   Jul-2018
# 1668            Yankee Flat Road          WARRENHEIP           C   Apr-2018
# 1669             Yarra Boulevard           KEW (EBB)        ABCD   Apr-2018
# 1670             Yarra Boulevard            RICHMOND          BC   Jun-2018
# 1671           Yarra Glen Bypass          YARRA GLEN           C   Mar-2018
# 1672                  Yarra Road          WONGA PARK           C   May-2018
# 1673  Yarrawonga Wangaratta Road           PEECHELBA          BC   Apr-2018
# 1674                 York Street       BALLARAT EAST         ABC   Jul-2018
# 1675               Yuille Street              MELTON          BC   Apr-2018
# 1676              Ziegler Parade          ALLANSFORD          BC   Apr-2018
#
#                                  full_location  row_index   index   longitude  \
# 0                       Agar Road, CORONET BAY          0     0.0  145.446520
# 1                Aitken Boulevard, CRAIGIEBURN          1     1.0  144.909917
# 2              Aitken Boulevard, ROXBURGH PARK          2     2.0  144.914952
# 3                     Aitken Street, ALEXANDRA          3     3.0  145.703606
# 4                       Albert Avenue, BORONIA          4     4.0  145.297632
# 5                        Albert Road, WARRAGUL          5     5.0  145.948668
# 6                     Alexanders Road, MORWELL          6     6.0  146.444067
# 7                        Allan Street, KYABRAM          7     7.0  145.049871
# 8                    Allenby Avenue, RESERVOIR          8     8.0  145.006307
# 9                      Allies Road, MYERS FLAT          9     9.0  144.200895
# 10                     Alma Street, TOOTGAROOK         10    10.0  144.850829
# 11              Ambrose Treacy Drive, BUNDOORA         11    11.0  145.071390
# 12                      Anakie Road, BELL PARK         12    12.0  144.332841
# 13                      Anderson Road, FAWKNER         13    13.0  144.966386
# 14                     Anderson Road, SUNSHINE         14    14.0  144.827243
# 15             Anglesea Road, FRESHWATER CREEK         15    15.0  144.269511
# 16                      Anzac Parade, BANDIANA         16    16.0  146.917102
# 17                       Anzac Road, TRAFALGAR         17    17.0  146.157171
# 18                  Apollo Road, TAYLORS LAKES         18    18.0  144.799303
# 19                        Ararat Road, STAWELL         19    19.0  142.772040
# 20             Ararat-Halls Gap Road, JALLUKAR         20    20.0  142.696873
# 21              Ararat-Halls Gap Road, MOYSTON         21    21.0  142.743252
# 22              Ararat-Halls Gap Road, POMONAL         22    22.0  142.650987
# 23                Ararat-Mortlake Road, ARARAT         23    23.0  142.920858
# 24          Armstrong Road, WYNDHAM VALE (NWB)         24    24.0  144.608277
# 25                 Armstrong Street, ELLIMINYT         25    25.0  143.574041
# 26                         Army Road, PAKENHAM         26    26.0  145.499748
# 27                   Army Road, PAKENHAM UPPER         27    27.0  145.497983
# 28                    Arthur Street, ST ALBANS         28    28.0  144.804234
# 29           Arthurs Creek Road, ARTHURS CREEK         29    29.0  145.178557
# ...                                        ...        ...     ...         ...
# 1647  Wodonga-Yackandandah Road, STAGHORN FLAT       1647  1647.0  146.927306
# 1648               Wollaston Road, WARRNAMBOOL       1648  1648.0  142.480450
# 1649                      Wonga Road, RINGWOOD       1649  1649.0  145.244809
# 1650                     Wood Street, FLINDERS       1650  1650.0  145.019685
# 1651                      Wood Street, PRESTON       1651  1651.0  145.018937
# 1652               Woodland Street, STRATHMORE       1652  1652.0  144.920525
# 1653                   Woodmason Road, BORONIA       1653  1653.0  145.282397
# 1654          Woods Point Road, EAST WARBURTON       1654  1654.0  145.803300
# 1655          Woods Point Road, MCMAHONS CREEK       1655  1655.0  145.854700
# 1656              Woori Yallock Road, COCKATOO       1656  1656.0  145.508535
# 1657               Woori Yallock Road, NANGANA       1657  1657.0  145.531380
# 1658                  Woorinen Road, SWAN HILL       1658  1658.0  143.498042
# 1659    Woorinen-Vinifera Road, WOORINEN NORTH       1659  1659.0  143.411200
# 1660    Woorinen-Vinifera Road, WOORINEN SOUTH       1660  1660.0  143.436164
# 1661                   Worsley Road, BANGHOLME       1661  1661.0  145.183875
# 1662                   Wright Street, SUNSHINE       1662  1662.0  144.826764
# 1663                     Wyandra Way, ROWVILLE       1663  1663.0  145.261795
# 1664                 Yallambie Road, YALLAMBIE       1664  1664.0  145.093442
# 1665                     Yan Yean Road, DOREEN       1665  1665.0  145.139070
# 1666                     Yan Yean Road, PLENTY       1666  1666.0  145.124013
# 1667                  Yan Yean Road, YARRAMBAT       1667  1667.0  145.132480
# 1668              Yankee Flat Road, WARRENHEIP       1668  1668.0  143.914683
# 1669                Yarra Boulevard, KEW (EBB)       1669  1669.0  145.022950
# 1670                 Yarra Boulevard, RICHMOND       1670  1670.0  145.016056
# 1671             Yarra Glen Bypass, YARRA GLEN       1671  1671.0  145.395968
# 1672                    Yarra Road, WONGA PARK       1672  1672.0  145.272355
# 1673     Yarrawonga Wangaratta Road, PEECHELBA       1673  1673.0  146.220930
# 1674                York Street, BALLARAT EAST       1674  1674.0  143.884188
# 1675                     Yuille Street, MELTON       1675  1675.0  144.591932
# 1676                Ziegler Parade, ALLANSFORD       1676  1676.0  142.606920
#
#        latitude                                  corrected address  \
# 0    -38.435757           Agar Rd, Coronet Bay VIC 3984, Australia
# 1    -37.594783       Aitken Blvd, Craigieburn VIC 3064, Australia
# 2    -37.624340     Aitken Blvd, Roxburgh Park VIC 3064, Australia
# 3    -37.187826           Aitken St, Alexandra VIC 3714, Australia
# 4    -37.854281            Albert Ave, Boronia VIC 3155, Australia
# 5    -38.162433            Albert Rd, Warragul VIC 3820, Australia
# 6    -38.218357         Alexanders Rd, Morwell VIC 3840, Australia
# 7    -36.313490              Allan St, Kyabram VIC 3620, Australia
# 8    -37.702616         Allenby Ave, Reservoir VIC 3073, Australia
# 9    -36.720110          Allies Rd, Myers Flat VIC 3556, Australia
# 10   -38.376989            Alma St, Tootgarook VIC 3941, Australia
# 11   -37.689538    Ambrose Treacy Dr, Bundoora VIC 3083, Australia
# 12   -38.104011           Anakie Rd, Bell Park VIC 3215, Australia
# 13   -37.695553           Anderson Rd, Fawkner VIC 3060, Australia
# 14   -37.785981          Anderson Rd, Sunshine VIC 3020, Australia
# 15   -38.269674  Anglesea Rd, Freshwater Creek VIC 3217, Australia
# 16   -36.141445                  Anzac Parade, Victoria, Australia
# 17   -38.210753            Anzac Rd, Trafalgar VIC 3824, Australia
# 18   -37.708565       Apollo Rd, Taylors Lakes VIC 3038, Australia
# 19   -37.071473             Ararat Rd, Stawell VIC 3380, Australia
# 20   -37.239327  Jallukar N Rd & Ararat-Halls Gap Rd, Moyston V...
# 21   -37.259597   Ararat-Halls Gap Rd, Moyston VIC 3377, Australia
# 22   -37.216028   Ararat-Halls Gap Rd, Pomonal VIC 3381, Australia
# 23   -37.315889     Mortlake-Ararat Rd, Ararat VIC 3377, Australia
# 24   -37.877724     Armstrong Rd, Wyndham Vale VIC 3024, Australia
# 25   -38.352039            Armstrong St, Colac VIC 3250, Australia
# 26   -38.048395              Army Rd, Pakenham VIC 3810, Australia
# 27   -38.035915              Army Rd, Pakenham VIC 3810, Australia
# 28   -37.735011           Arthur St, St Albans VIC 3021, Australia
# 29   -37.570183  Arthurs Creek Rd, Arthurs Creek VIC 3099, Aust...
# ...         ...                                                ...
# 1647 -36.248944  Yackandandah - Wodonga Rd, Staghorn Flat VIC 3...
# 1648 -38.354261      Wollaston Rd, Warrnambool VIC 3280, Australia
# 1649 -37.792184             Wonga Rd, Ringwood VIC 3134, Australia
# 1650 -38.470220              Wood St, Flinders VIC 3929, Australia
# 1651 -37.734974               Wood St, Preston VIC 3072, Australia
# 1652 -37.742649        Woodland St, Strathmore VIC 3041, Australia
# 1653 -37.852288          Woodmason Rd, Boronia VIC 3155, Australia
# 1654 -37.713312  Woods Point Rd, East Warburton VIC 3799, Austr...
# 1655 -37.664399  Woods Point Rd, Mcmahons Creek VIC 3799, Austr...
# 1656 -37.902938     Woori Yallock Rd, Cockatoo VIC 3781, Australia
# 1657 -37.877840      Woori Yallock Rd, Nangana VIC 3781, Australia
# 1658 -35.311008                   Woorinen Rd, Victoria, Australia
# 1659 -35.236959  Woorinen-Vinifera Rd, Woorinen North VIC 3589,...
# 1660 -35.272130  Woorinen-Vinifera Rd, Woorinen South VIC 3588,...
# 1661 -38.055380          Worsley Rd, Bangholme VIC 3175, Australia
# 1662 -37.795508            Wright St, Sunshine VIC 3020, Australia
# 1663 -37.911200          Wyandra Way, Rowville VIC 3178, Australia
# 1664 -37.720869        Yallambie Rd, Yallambie VIC 3085, Australia
# 1665 -37.600084            Yan Yean Rd, Doreen VIC 3754, Australia
# 1666 -37.662316            Yan Yean Rd, Plenty VIC 3090, Australia
# 1667 -37.638575         Yan Yean Rd, Yarrambat VIC 3091, Australia
# 1668 -37.591126     Yankee Flat Rd, Warrenheip VIC 3352, Australia
# 1669 -37.789441              1 Yarra Blvd, Kew VIC 3101, Australia
# 1670 -37.825159           Yarra Blvd, Richmond VIC 3121, Australia
# 1671 -37.651948  Yarra Glen Bypass, Yarra Glen VIC 3775, Australia
# 1672 -37.753390           Yarra Rd, Wonga Park VIC 3115, Australia
# 1673 -36.168495  Wangaratta-Yarrawonga Rd, Peechelba VIC 3678, ...
# 1674 -37.569570         York St, Ballarat East VIC 3350, Australia
# 1675 -37.679148              Yuille St, Melton VIC 3337, Australia
# 1676 -38.387095     Ziegler Parade, Allansford VIC 3277, Australia
#
#         extracted_on
# 0     2018-August-06
# 1     2018-August-06
# 2     2018-August-06
# 3     2018-August-06
# 4     2018-August-06
# 5     2018-August-06
# 6     2018-August-06
# 7     2018-August-06
# 8     2018-August-06
# 9     2018-August-06
# 10    2018-August-06
# 11    2018-August-06
# 12    2018-August-06
# 13    2018-August-06
# 14    2018-August-06
# 15    2018-August-06
# 16    2018-August-06
# 17    2018-August-06
# 18    2018-August-06
# 19    2018-August-06
# 20    2018-August-06
# 21    2018-August-06
# 22    2018-August-06
# 23    2018-August-06
# 24    2018-August-06
# 25    2018-August-06
# 26    2018-August-06
# 27    2018-August-06
# 28    2018-August-06
# 29    2018-August-06
# ...              ...
# 1647  2018-August-06
# 1648  2018-August-06
# 1649  2018-August-06
# 1650  2018-August-06
# 1651  2018-August-06
# 1652  2018-August-06
# 1653  2018-August-06
# 1654  2018-August-06
# 1655  2018-August-06
# 1656  2018-August-06
# 1657  2018-August-06
# 1658  2018-August-06
# 1659  2018-August-06
# 1660  2018-August-06
# 1661  2018-August-06
# 1662  2018-August-06
# 1663  2018-August-06
# 1664  2018-August-06
# 1665  2018-August-06
# 1666  2018-August-06
# 1667  2018-August-06
# 1668  2018-August-06
# 1669  2018-August-06
# 1670  2018-August-06
# 1671  2018-August-06
# 1672  2018-August-06
# 1673  2018-August-06
# 1674  2018-August-06
# 1675  2018-August-06
# 1676  2018-August-06
#
# [1677 rows x 11 columns]

# %%
merged_data.columns
# Out:
# Index(['LOCATION', 'SUBURB', 'Reason Code', 'Audit Date', 'full_location',
#        'row_index', 'index', 'longitude', 'latitude', 'corrected address',
#        'extracted_on'],
#       dtype='object')

# %% [markdown]
# ## Correcting isssue with addresses outside of victoria

# %%
victoria_master_bounds = [140.96168199600004,
 -39.159189527999956,
 149.9762909950001,
 -33.98042558699996]

for index in range(merged_data.shape[0]):
    long = merged_data.loc[index, 'longitude']
    lat = merged_data.loc[index, 'latitude']
    
    if long >= victoria_master_bounds[0] and long <= victoria_master_bounds[2] and lat >= victoria_master_bounds[1] and lat <= victoria_master_bounds[3]:
        merged_data.loc[index, "inside_victoria_bounds"] = "True"
    else:
        merged_data.loc[index, "inside_victoria_bounds"] = "False"
        long,lat,formatted_address = return_address_dictionary(merged_data.loc[index, "full_location"] + ", VICTORIA, AUSTRALIA")
        print(long, lat,formatted_address)
        merged_data.loc[index, "longitude"] = long 
        merged_data.loc[index, "latitude"] = lat
        merged_data.loc[index, "corrected_address"] = formatted_address
# Out:
# 142.0146467 -37.7391806 Burns St, Hamilton VIC 3300, Australia
# 144.5724233 -38.1648882 Clifton Springs Rd, Clifton Springs VIC 3222, Australia
# 141.5973179 -38.3319956 Garden St, Portland VIC 3305, Australia
# 142.0343551 -37.7455669 George St, Hamilton VIC 3300, Australia
# 142.1886542 -36.7405239 Golf Course Rd, Haven VIC 3401, Australia
# 142.0211593 -37.7314935 King St, Hamilton VIC 3300, Australia
# 141.6011746 -38.329709 New St, Portland VIC 3305, Australia
# 144.6949226 -37.7018025 Plumpton Road, Plumpton VIC 3335, Australia
# 143.1473452 -38.2329527 Princes Hwy, Camperdown VIC 3260, Australia
# 145.0937179 -37.8936073 Princes Hwy, Victoria, Australia
# 145.1415088 -38.1092354 Seaford Rd, Seaford VIC 3198, Australia
# 144.8091884 -37.7565399 St Albans Rd, St Albans VIC 3021, Australia
# 144.7274965 -37.590355 The Avenue, Sunbury VIC 3429, Australia
# 142.02475 -37.7333986 Victoria St, Hamilton VIC 3300, Australia
# 144.7401475 -36.357462 Webb Rd, Rochester VIC 3561, Australia

# %%
merged_data.head()
# Out:
#            LOCATION         SUBURB Reason Code Audit Date  \
# 0         Agar Road    CORONET BAY          BC   Jul-2018
# 1  Aitken Boulevard    CRAIGIEBURN         ABC   Dec-2017
# 2  Aitken Boulevard  ROXBURGH PARK         ABC   Dec-2017
# 3     Aitken Street      ALEXANDRA           C   Apr-2018
# 4     Albert Avenue        BORONIA           C   Jan-2018
#
#                      full_location  row_index  index   longitude   latitude  \
# 0           Agar Road, CORONET BAY          0    0.0  145.446520 -38.435757
# 1    Aitken Boulevard, CRAIGIEBURN          1    1.0  144.909917 -37.594783
# 2  Aitken Boulevard, ROXBURGH PARK          2    2.0  144.914952 -37.624340
# 3         Aitken Street, ALEXANDRA          3    3.0  145.703606 -37.187826
# 4           Albert Avenue, BORONIA          4    4.0  145.297632 -37.854281
#
#                                 corrected address    extracted_on  \
# 0        Agar Rd, Coronet Bay VIC 3984, Australia  2018-August-06
# 1    Aitken Blvd, Craigieburn VIC 3064, Australia  2018-August-06
# 2  Aitken Blvd, Roxburgh Park VIC 3064, Australia  2018-August-06
# 3        Aitken St, Alexandra VIC 3714, Australia  2018-August-06
# 4         Albert Ave, Boronia VIC 3155, Australia  2018-August-06
#
#   inside_victoria_bounds corrected_address
# 0                   True               NaN
# 1                   True               NaN
# 2                   True               NaN
# 3                   True               NaN
# 4                   True               NaN

# %%
merged_data["inside_victoria_bounds"].value_counts()
# Out:
# True    1677
# Name: inside_victoria_bounds, dtype: int64

# %%
merged_data.to_csv("geocoded_mobile_speed_cameras_august_6_2018_final.csv", index = False)
